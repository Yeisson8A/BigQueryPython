# %%
pip install google-cloud
# Out:
# Collecting google-cloud
#   Downloading google_cloud-0.34.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Downloading google_cloud-0.34.0-py2.py3-none-any.whl (1.8 kB)
# Installing collected packages: google-cloud
# Successfully installed google-cloud-0.34.0

# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-30.8.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from Faker) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Downloading Faker-30.8.0-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.0 MB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-30.8.0

# %%
# Variables
project = "xxxxxxxx"
my_dataset = "py_dataset20241021"
my_table = "py_table20241021"
src_bucket = "bkt-dev-src20241021"
destination_bucket = "bkt-dev-dst20241021"

# %%
from google.cloud import bigquery
from google.cloud import storage
from google.cloud.bigquery import LoadJobConfig
from faker import Faker
import pandas as pd
import csv
import datetime
import time

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# Crear función para crear tabla en BigQuery
def create_bq():
    client = bigquery.Client(project=project)

    dataset_id = my_dataset
    table_id = my_table

    schema = [
        bigquery.SchemaField("id", "INTEGER"),
        bigquery.SchemaField("name", "STRING"),
        bigquery.SchemaField("email", "STRING"),
        bigquery.SchemaField("description","STRING"),
        bigquery.SchemaField("address","STRING"),
        bigquery.SchemaField("city","STRING"),
        bigquery.SchemaField("state","STRING"),
        bigquery.SchemaField("country","STRING"),
        bigquery.SchemaField("birthdate","DATE"),
        bigquery.SchemaField("password","STRING"),
        bigquery.SchemaField("last_login","TIMESTAMP")
    ]

    table_ref = client.dataset(my_dataset).table(my_table)
    table = bigquery.Table(table_ref, schema=schema)

    try:
        dataset = client.create_dataset(my_dataset)
        print(f"Created dataset {my_dataset}")
    except:
        print(f"Dataset {my_dataset} already exists")

    try:
        table = client.create_table(table)
        print(f"Created table {table_id}")
    except:
        print(f"Table {table_id} already exists")

# %%
# Crear función para generar datos en tabla origen BigQuery
def generate_data(num_rows):
    fake = Faker()
    now = datetime.datetime.now()
    filename = "data_" + now.strftime("%Y%m%d%H%M%S") + ".csv"


    with open(filename, 'w', newline='') as csvfile:
        fieldnames = ['id', 'name', 'email', 'description', 'address', 'city', 'state',
                      'country', 'birthdate', 'password', 'last_login']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for i in range(num_rows):
            writer.writerow(
                {
                    'id': fake.random_int(),
                    'name': fake.name(),
                    'email': fake.email(),
                    'description': fake.sentence(),
                    'address': fake.street_address(),
                    'city': fake.city(),
                    'state': fake.state(),
                    'country': fake.country(),
                    'birthdate': fake.date(),
                    'password': fake.password(),
                    'last_login': fake.date_time()
                }
            )
    print (f"Data generated with {num_rows} records")

    client = storage.Client()
    bucket_name = src_bucket
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(filename)
    blob.upload_from_filename(filename)
    print(f"File {filename} Uploaded to {bucket_name}")

    return filename

# %%
# Crear función para cargar datos de tabla origen BigQuery
def load_bq(filename):
    client = bigquery.Client(project=project)
    filename = filename
    table_ref = client.dataset(my_dataset).table(my_table)
    job_config = LoadJobConfig()
    job_config.source_format = bigquery.SourceFormat.CSV
    job_config.skip_leading_rows = 1
    job_config.autodetect = True

    uri = f'gs://{src_bucket}/{filename}'
    load_job = client.load_table_from_uri(uri, table_ref, job_config=job_config)
    load_job.result()
    time.sleep(10)
    num_rows = load_job.output_rows
    print(f"{num_rows} rows loaded into {my_table}.")

# %%
# Crear función para extraer datos de tabla origen BigQuery hacia tabla destino
def extract_bq():
    client = bigquery.Client(project=project)
    dataset_ref = client.dataset(my_dataset)
    table_ref = dataset_ref.table(my_table)
    job_config = bigquery.ExtractJobConfig()
    job_config.compression = 'GZIP'
    job_config.field_delimiter = ','
    job_config.print_header = False

    now = datetime.datetime.now()
    filename = "bqextract_" + now.strftime("%Y%m%d%H%M%S") + ".csv"
    destination_uri = f'gs://{destination_bucket}/{filename}'

    extract_job = client.extract_table(table_ref, destination_uri, job_config=job_config)

    extract_job.result()

    print('Data extracted from table {} and loaded into GCS bucket {}.'.format(table_ref.path, destination_uri))

# %%
# Crear tabla origen en BigQuery
create_bq()
# Out:
# Created dataset py_dataset20241021
# Created table py_table20241021

# %%
# Generar archivo con datos a cargar
filename = generate_data(500)
# Out:
# Data generated with 500 records
# File data_20241021155117.csv Uploaded to bkt-dev-src20241021

# %%
# Cargar datos del archivo a tabla origen en BigQuery
load_bq(filename)
# Out:
# 500 rows loaded into py_table20241021.

# %%
# Consultar datos de tabla origen en BigQuery
client = bigquery.Client(project=project)
query = f"SELECT * FROM `{project}.py_dataset20241021.py_table20241021` LIMIT 1000"
query_job = client.query(query)
df = query_job.to_dataframe()
df.head(50)
# Out:
#       id                 name                         email  \
# 0    194    Brandon Vance Jr.          joysmith@example.com
# 1   6274        Barry Sanders        jonescraig@example.com
# 2    700         Seth Montoya        hallstacey@example.org
# 3   8625       Katherine Hart         hilltyler@example.org
# 4   7971         Peter Wright           brian94@example.org
# 5   2768        Megan Solomon        baileymike@example.net
# 6   2371         Ronald Green           igreene@example.org
# 7   9567          Anne Martin        sdavenport@example.org
# 8   5392         Jeffery Bell     ronaldstewart@example.net
# 9    256        Justin Rivera             tpage@example.com
# 10  3060     Claire Rodriguez     bradleyjavier@example.org
# 11   878       Ronald Jackson            mary43@example.net
# 12   343         Rebecca Khan      monicaparker@example.net
# 13  8086         Renee Wright          evelyn11@example.org
# 14  5750         Justin Ayers           fthomas@example.org
# 15  4416     Allen Johnson MD        durantammy@example.net
# 16  6727          Jack Wright    lawsonmitchell@example.net
# 17   460          Keith Woods   gonzalesjeffrey@example.net
# 18  8402           Adam Brown  kristinhernandez@example.org
# 19  4807          James Olson     hardykimberly@example.net
# 20  8613  Christopher Aguilar      barbarascott@example.org
# 21  5806       Alexander West       danielmyers@example.net
# 22  8128             Amy King          daniel22@example.net
# 23  1269       Jason Anderson     debraanderson@example.com
# 24  2202       Latoya Ramirez       wendyporter@example.org
# 25  8470        Russell Jones      gilesjeffrey@example.net
# 26  9499         Shawn Gibson      salazarsarah@example.org
# 27  4983      Jeffrey Ramirez         heather99@example.net
# 28  4049          Glenn Brown    dariuspeterson@example.org
# 29  3610        Lisa Williams          dramirez@example.net
# 30  1748       Kimberly Evans     justingregory@example.net
# 31  4545       Kendra Collins          shelly93@example.com
# 32  9585       Isabella Yates           shawn65@example.com
# 33  3221    Jennifer Robinson           stacy29@example.net
# 34  5642      Elizabeth Grant         patrick44@example.net
# 35  1985            Angela Wu       jackiejones@example.net
# 36   595     Rebecca Matthews       kaitlynmack@example.org
# 37  8825          Maria Brown           yoliver@example.net
# 38  4622        Deborah Myers   michaelfriedman@example.org
# 39  7438         Kim Mcintosh         krystal75@example.net
# 40   907       Ruben Friedman       newmanbryan@example.org
# 41  9208             Ryan May     morganbarrett@example.net
# 42  8142       Peter Whitaker    andrewerickson@example.com
# 43  3580          Travis Hull        jorgegomez@example.com
# 44   474      Jaime Blackwell       smithaustin@example.net
# 45   548         Kevin Palmer     mariaodonnell@example.org
# 46  3012        Cheryl Martin         carolyn06@example.org
# 47  7441       Heather Howard         patrick70@example.net
# 48  6238          Mark Walker        georgejohn@example.net
# 49  5496             Carl Lee           rwarner@example.net
#
#                                           description  \
# 0       Perform create record move personal home kid.
# 1         Sure sign foot television impact town rule.
# 2                             Matter find understand.
# 3     Career deal deal big start series nothing deal.
# 4                                  I including truth.
# 5                         Dog international help let.
# 6                             Media become have like.
# 7              Mouth citizen community picture shake.
# 8                          Anything before side then.
# 9   Company professional drop compare certainly to...
# 10                         Prevent employee interest.
# 11            Authority current see truth new across.
# 12  Father agree sing produce animal pick gun happen.
# 13                   Approach draw key hand activity.
# 14                               Wait theory picture.
# 15  Hope executive manage recent determine sort sp...
# 16                               State skill realize.
# 17                    Hand store of call list threat.
# 18                 Fund street treat show view local.
# 19                          Doctor involve know fall.
# 20             Everybody sport control speech letter.
# 21              Toward watch base small great should.
# 22                                  Already two wind.
# 23                                Set others herself.
# 24                     Far since bad treatment issue.
# 25                Dark cause beyond treatment better.
# 26                            Least next consider by.
# 27                                 War hotel address.
# 28                     Shoulder safe several history.
# 29             Movie play western these whatever ten.
# 30      Either factor true itself central experience.
# 31                         Also me Republican artist.
# 32                        Song interest however true.
# 33              Time more check woman finish society.
# 34                              Service game key Mrs.
# 35                            Great bag seek account.
# 36            Continue drop staff laugh level forget.
# 37                       Turn rich these performance.
# 38                               Rather actually bed.
# 39            For yourself present wonder pay edge I.
# 40                      Impact music include citizen.
# 41                    Medical prevent window culture.
# 42                    Woman plan attorney fire chair.
# 43         Feel really worker part once discover yes.
# 44            Entire inside white girl million style.
# 45                  Mission collection wonder action.
# 46                  Whom different conference garden.
# 47                         Simply wish trial compare.
# 48                              Much fine gas former.
# 49              West value write dinner any actually.
#
#                             address                  city  state  \
# 0                  398 Hall Springs       South Brendaton   Iowa
# 1                74913 Kelly Branch         Hendersonberg   Iowa
#
#                          last_login
# 0  2019-12-04 05:33:59.786843+00:00
# 1  1985-02-02 07:28:47.943444+00:00
# 2  2001-07-15 18:50:39.063167+00:00
# 3  2006-01-16 18:16:13.369839+00:00
# 4  2001-01-07 15:07:48.122758+00:00
# 5  1998-10-28 21:18:04.315860+00:00
# 6  1992-01-23 05:31:04.166546+00:00
# 7  2012-08-05 01:59:46.753078+00:00
# 8  1985-05-16 00:00:05.099731+00:00
# 9  2018-08-29 04:21:34.926075+00:00
# 10 1999-05-07 12:41:19.894477+00:00
# 11 2012-02-02 12:02:47.223759+00:00
# 12 2006-06-13 19:40:20.340122+00:00
# 13 1977-01-26 01:51:55.156061+00:00
# 14 1986-04-06 05:05:35.368564+00:00
# 15 1992-10-16 16:12:54.572463+00:00
# 16 1970-05-02 14:48:57.682344+00:00
# 17 2003-05-13 12:12:13.998571+00:00
# 18 1995-02-13 16:42:59.431128+00:00
# 19 1974-04-04 14:01:40.304364+00:00
# 20 1998-09-07 06:07:22.812884+00:00
# 21 2021-08-05 20:46:11.353839+00:00
# 22 1999-01-26 02:57:44.966187+00:00
# 23 1979-05-23 23:20:14.514981+00:00
# 24 1983-11-23 01:19:20.473716+00:00
# 25 2010-01-05 14:22:30.669420+00:00
# 26 2012-04-25 22:34:24.187555+00:00
# 27 1978-10-28 08:42:34.137131+00:00
# 28 2002-03-31 07:15:18.197369+00:00
# 29 2023-06-25 17:52:28.989444+00:00
# 30 1998-12-05 22:42:50.988130+00:00
# 31 1979-05-10 11:01:58.635126+00:00
# 32 2007-11-07 03:27:06.184176+00:00
# 33 2008-09-22 09:10:27.213436+00:00
# 34 1997-02-05 20:12:56.033363+00:00
# 35 1972-06-22 00:13:00.357945+00:00
# 36 1974-05-04 10:47:03.835183+00:00
# 37 2003-03-09 00:14:19.590843+00:00
# 38 2010-01-21 06:17:36.562141+00:00
# 39 1976-09-28 12:26:35.103604+00:00
# 40 1995-08-05 05:38:45.023751+00:00
# 41 2013-12-25 01:08:39.018533+00:00
# 42 1993-09-17 04:58:24.010955+00:00
# 43 1996-12-13 10:17:42.403108+00:00
# 44 1980-09-04 19:02:20.386593+00:00
# 45 1980-01-12 23:34:45.014803+00:00
# 46 1984-01-19 05:07:55.196630+00:00
# 47 2018-07-18 14:36:29.271914+00:00
# 48 2019-11-03 18:13:58.782694+00:00
# 49 2006-11-26 19:27:17.379344+00:00

# %%
# Extraer datos de tabla origen y cargar en bucket destino
extract_bq()
# Out:
# Data extracted from table /projects/bigquerypython-439314/datasets/py_dataset20241021/tables/py_table20241021 and loaded into GCS bucket gs://bkt-dev-dst20241021/bqextract_20241021160354.csv.

# %%
# Mostrar archivo creado por la ETL en bucket destino
client = storage.Client()
blobs = client.list_blobs(destination_bucket)

for blob in blobs:
    print(blob.name)
# Out:
# bqextract_20241021160354.csv
